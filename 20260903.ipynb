# %% [markdown]
# <a href="https://colab.research.google.com/github/26408-ux/10708/blob/main/20260903.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("현재 온도는 20도 입니다")
# Out:
# 현재 온도는 20도 입니다

# %%
a = 20
b = 50
print('현재 온도는 %d도 습도는 %d%% 입니다.'%(a, b))
# Out:
# 현재 온도는 20도 습도는 50% 입니다.

# %%
print('직각은 {c}도, 원주율은 {1:0.2f}')
# Out:
# 직각은 {c}도, 원주율은 {1:0.2f}

# %%
print('동해 물과 '백두산'이')
print('마르고 닳도록')
print('하느님이 보우하사')
print('우리나라 만세')
print('무궁화 삼천리', end = 9' ')
print('화려 강산')
print('대한 사람, "대한"으로 길이 보전하세.')
print('2026' '05', '20', sep='-')
# Out:
#   File "/tmp/ipykernel_6647/2873992820.py", line 1
#     print('동해 물과 '백두산'이')
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('품목wt\t가격\twt개수wn사과는 2000원 바나나 3000원')
# Out:
# 품목wt	가격	wt개수wn사과는 2000원 바나나 3000원
