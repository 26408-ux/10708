# %% [markdown]
# <a href="https://colab.research.google.com/github/26408-ux/10708/blob/main/20260922.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = {}
b = {88: 'seoul', 24: 'paris', 'num': [10,20]}
c = {'name': 'kim', 'name': 'lee'}
print(a, type(a))
print(len(b))
print(b[88])
print(c['name'])
# Out:
# {} <class 'dict'>
# 3
# seoul
# lee

# %%
a = {88: 'london', 20: 'tokyo'}
a[88] = 'seoul'
a[24] = 'paris'
del a[20]
print(a)
# Out:
# {88: 'seoul', 24: 'paris'}

# %%
dic = {'grape': '포도', 'apple': '사과'}
print(dic)
print(sorted(dic))
print('apple' in dic)
# Out:
# {'grape': '포도', 'apple': '사과'}
# ['apple', 'grape']
# True

# %%
print(dic.keys())
print(dic.values())
print(sorted(dic.values()))
print(dic.items())
p = dic.pop('apple')
print(p)
print(dic)
print(dic.get('grape'))
print(dic.get('apple'))
print(dic.get('apple', '없음'))
dic.clear()
print(dic)
# Out:
# dict_keys(['grape', 'apple'])
# dict_values(['포도', '사과'])
# ['사과', '포도']
# dict_items([('grape', '포도'), ('apple', '사과')])
# 사과
# {'grape': '포도'}
# 포도
# None
# 없음
# {}
