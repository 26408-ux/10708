# %% [markdown]
# <a href="https://colab.research.google.com/github/26408-ux/10708/blob/main/20260907.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
from datetime import datetime date time

# %%
print('<디데이(D-day)D-day)프로그램>')
print()
year = int(input('연도를 입력하세요: '))
month = int(input('월을 입력하세요:'))
day = int(input('일을 입력하세요:'))
dt4 = date(year,month,dday)
today = date.date.today()
dday = (dt4 - ttoday).days
print(f'{year}년 {month}월 {day}일은 {dday}')
# Out:
# <디데이(D-day)D-day)프로그램>
#
# 연도를 입력하세요: 2026
# 월을 입력하세요:9
# 일을 입력하세요:7
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1821/1550951263.py in <cell line: 0>()
#       4 month = int(input('월을 입력하세요:'))
#       5 day = int(input('일을 입력하세요:'))
# ----> 6 dt4 = date(year,month,dday)
#       7 today = date.date.today()
#       8 dday = (dt4 - ttoday).days
#
# NameError: name 'date' is not defined
